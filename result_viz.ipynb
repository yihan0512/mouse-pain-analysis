# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('./mouse_pain_deepethogram/DATA/B_BR_5dp3i_body/B_BR_5dp3i_body_predictions.csv')

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'background', 'left_hindpaw_biting/licking',
#        'right_hindpaw_biting/licking', 'left_hindpaw_lifting',
#        'right_hindpaw_lifting', 'left_hindlimb_licking',
#        'right_hindlimb_licking', 'genital_licking',
#        'bout_of_hindpaw_scratchingandbiting', 'left_forepaw_licking',
#        'right_forepaw_licking', 'left_forepaw_lifting_or_suspending',
#        'right_forepaw_lifting_or_suspending', 'rearing_against_wall',
#        'free_rearing', 'face_grooming', 'back_grooming', 'belly_grooming',
#        'tail_grooming'],
#       dtype='object')

# %%
for i in range(len(df.columns)):
    plt.figure()
    plt.plot(df[df.columns[4]])

# %%
df = pd.read_csv('./mouse_pain_deepethogram/DATA/B_BR_5dp3i_body/B_BR_5dp3i_body_labels.csv')
for i in range(len(df.columns)):
    plt.figure()
    plt.plot(df[df.columns[i]])

# %%
plt.plot(df[df.columns[4]])
